# %%
#pip install sciunit quantities efel scipy json2html neurom

# %%
#% matplotlib notebook
# %matplotlib inline
from json2html import *
import quantities
from quantities import mV, nA
import IPython
import json
import collections
import pkg_resources
import numpy

#import sciunit
#from hippounit import models
from hippounit import tests
from hippounit.utils_50Ra_major_nmda import ModelLoader_synapse_on_Passive_Spine, ModelLoader_synapse_on_Active_Spine
from hippounit.utils_50Ra_major_nmda import ModelLoader_Modellke, ModelLoader_synapse_on_Existing_Spine
#from hippounit import capabilities
#import matplotlib.pyplot as plt

from neuron import h
# Out:
# Invalid MIT-MAGIC-COOKIE-1 key

# %%
import hippounit
print(hippounit.__file__)
# Out:
# /home/tarluca/Modellke_story/hippounit_Spine_project_20221102/hippounit/hippounit/__init__.py

# %% [markdown]
# # Synapses arrive at dendritic shaft - Active F-factor

# %% [markdown]
# ## Instantiating the model

# %%
#all the outputs will be saved here. It will be an argument to the test.
"""Edit the line below"""
base_directory = '/mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/'

# path to mod files
"""Edit the line below"""
mod_files_path = "/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/mod_files/"

# user function path
"""Edit the line below"""
user_function_path = '/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/usr_fun_model_full_rework7.txt'

#Load cell model
model = ModelLoader_Modellke(mod_files_path = mod_files_path, user_function_path = user_function_path)

# path to hoc file
# the model must not display any GUI!!
"""Edit the line below"""
model.hocpath = "/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/load_model_na_inhomo_minimal_model_full_soma_f_fact_true_diam_active_spine_KA_fact_50Ra.hoc"
# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'soma'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'trunk'
model.TuftSecList_name = 'tuft'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'

model.BasalSecList_name = 'basal_dendrites'

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -70
model.celsius = 33

model.c_step_start = 0.000004
model.c_step_stop = 0.0000004
model.c_minmax = numpy.array([0.000004, 0.004])

# %% [markdown]
# ## Somatic Features Test

# %%
# Load target data
"""Edit the line below"""
with open('/home/tarluca/Modellke_story/hippounit_Spine_project_20221102/hippounit/target_features/CA1_valid_data_uniform.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>AHP1_depth_from_peak.Step0.15</th><td><table border="1"><tr><th>Std</th><td>6.1525</td></tr><tr><th>Mean</th><td>88.8163</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.15</td></tr><tr><th>Type</th><td>AHP1_depth_from_peak</td></tr></table></td></tr><tr><th>AHP1_depth_from_peak.Step0.2</th><td><table border="1"><tr><th>Std</th><td>6.1635</td></tr><tr><th>Mean</th><td>86.9675</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.2</td></tr><tr><th>Type</th><td>AHP1_depth_from_peak</td></tr></table></td></tr><tr><th>AHP1_depth_from_peak.Step0.25</th><td><table border="1"><tr><th>Std</th><td>5.9553</td></tr><tr><th>Mean</th><td>85.5763</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.25</td></tr><tr><th>Type</th><td>AHP1_depth_from_peak</td></tr></table></td></tr><tr><th>AHP2_depth_from_peak.Step0.15</th><td><table border="1"><tr><th>Std</th><td>5.9594</td></tr><tr><th>Mean</th><td>87.7101</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.15</td></tr><tr><th>Type</th><td>AHP2_depth_from_peak</td></tr></table></td></tr><tr><th>AHP2_depth_from_peak.Step0.2</th><td><table border="1"><tr><th>Std</th><td>6.0822</td></tr><tr><th>Mean</th><td>84.8261</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.2</td></tr><tr><th>Type</th><td>AHP2_depth_from_peak</td></tr></table></td></tr><tr><th>AHP2_depth_from_peak.Step0.25</th><td><table border="1"><tr><th>Std</th><td>5.4884</td></tr><tr><th>Mean</th><td>82.1864</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.25</td></tr><tr><th>Type</th><td>AHP2_depth_from_peak</td></tr></table></td></tr><tr><th>AHP_depth.Step0.15</th><td><table border="1"><tr><th>Std</th><td>0.6985</td></tr><tr><th>Mean</th><td>12.351</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.15</td></tr><tr><th>Type</th><td>AHP_depth</td></tr></table></td></tr><tr><th>AHP_depth.Step0.2</th><td><table border="1"><tr><th>Std</th><td>0.6834</td></tr><tr><th>Mean</th><td>13.5449</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.2</td></tr><tr><th>Type</th><td>AHP_depth</td></tr></table></td></tr><tr><th>AHP_depth.Step0.25</th><td><table border="1"><tr><th>Std</th><td>0.5675</td></tr><tr><th>Mean</th><td>14.5688</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.25</td></tr><tr><th>Type</th><td>AHP_depth</td></tr></table></td></tr><tr><th>AHP_depth_abs.Step0.15</th><td><table border="1"><tr><th>Std</th><td>1.5257</td></tr><tr><th>Mean</th><td>-52.4641</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.15</td></tr><tr><th>Type</th><td>AHP_depth_abs</td></tr></table></td></tr><tr><th>AHP_depth_abs.Step0.2</th><td><table border="1"><tr><th>Std</th><td>1.2849</td></tr><tr><th>Mean</th><td>-51.3043</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.2</td></tr><tr><th>Type</th><td>AHP_depth_abs</td></tr></table></td></tr><tr><th>AHP_depth_abs.Step0.25</th><td><table border="1"><tr><th>Std</th><td>1.074</td></tr><tr><th>Mean</th><td>-50.6601</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.25</td></tr><tr><th>Type</th><td>AHP_depth_abs</td></tr></table></td></tr><tr><th>AHP_depth_diff.Step0.15</th><td><table border="1"><tr><th>Std</th><td>0.1279</td></tr><tr><th>Mean</th><td>0.5436</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.15</td></tr><tr><th>Type</th><td>AHP_depth_diff</td></tr></table></td></tr><tr><th>AHP_depth_diff.Step0.2</th><td><table border="1"><tr><th>Std</th><td>0.0745</td></tr><tr><th>Mean</th><td>0.432</td></tr><tr><th>Weight</th><td>1</td></tr><tr><th>Stimulus</th><td>Step0.2</td></tr><tr><th>Type</th><td>AHP_depth_diff</td></tr></table></td></tr><tr><th>AHP_depth_diff.Step0.25</th><td><table border="1"><tr><th>Std</th><td>0.0406</td></tr><tr><th>Mean</th><td>0.3704</td></tr><tr><th>Weight</th> ...

# %%
#stimuli
import pkg_resources
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_CA1_valid_data.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Instantiate the test class
test = tests.SomaticFeaturesTest(observation = observation, config=config, save_all = True, force_run=True, show_plot = True, base_directory = base_directory)

# Number of parallel processes
test.npool = 20

"""Edit the line below"""
f = open('/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/results_ca1_results/last_13_blocking.csv')
lines = []
for l in f.readlines():
    #print l.strip().split(',')
    lines.append(l.strip().split(','))
f.close()

for i in range(1, len(lines)):
    parameters = [float(j) for j in lines[i]]
    #lines[i].pop(0)
    parameters.pop(0)
    print(parameters)
    
    model.parameters = parameters
    # outputs will be saved in folders named like this:
    """Edit the line below"""
    model.name="ca1_pc_"+str(i)
    if numpy.isnan(parameters[0]):
        print('Parameters are nan')
        pass
    else:
        try:
            #Run the test 
            score = test.judge(model)
            #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
            score.summarize()

        except Exception as e:
            print('Model: ' + model.name + ' could not be run')
            print(e)
            pass
# Out:
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: -0.1 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.05 on model: ca1_pc_1 at: soma(0.5)- running amplitude: -0.2 on model: ca1_pc_1 at: soma(0.5)
#
#
# - running amplitude: 0.15 on model: ca1_pc_1 at: soma(0.5)- running amplitude: -0.15 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_1 at: soma(0.5)
#
#
# - running amplitude: 0.1 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: -0.25 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: -0.05 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_1/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): initburst_sahp.Step0.25, initburst_sahp_ssse.Step0.25, initburst_sahp_vb.Step0.25, min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 291/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_1/
# [-47.7233744163709, 0.0, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: -0.15 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: -0.2 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: -0.25 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: -0.05 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: -0.1 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.05 on model: ca1_pc_2 at: soma(0.5)
#
# - running amplitude: 0.2 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.15 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.1 on model: ca1_pc_2 at: soma(0.5)
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_2/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): initburst_sahp.Step0.25, initburst_sahp_ssse.Step0.25, initburst_sahp_vb.Step0.25, min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 291/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_2/
# [-47.7233744163709, 0.011401720134011, 0.0, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: -0.05 on model: ca1_pc_3 at: soma(0.5)- running amplitude: -0.15 on model: ca1_pc_3 at: soma(0.5)
#
# - running amplitude: 0.25 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: -0.25 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: -0.2 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.15 on model: ca1_pc_3 at: soma(0.5)
#
# - running amplitude: -0.1 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_3 at: soma(0.5)
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP1_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP1_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP1_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP2_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP2_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP2_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_abs, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_abs, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_abs, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_diff, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_diff, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_diff, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_depth_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_time_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_time_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AHP_time_from_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP1_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP1_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP1_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_AP1_peak_diff, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_AP1_peak_diff, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_AP1_peak_diff, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_amp, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_amp, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_amp, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_voltage, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_voltage, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_voltage, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_peak, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude_from_voltagebase, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude_from_voltagebase, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_amplitude_from_voltagebase, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_voltage, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_voltage, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_voltage, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_fall_rate, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_fall_rate, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_fall_rate, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_fall_time, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_fall_time, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_fall_time, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_height, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_height, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_height, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_rate, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_rate, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_rate, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_rate_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_rate_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_rate_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_time, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_time, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_rise_time, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_width, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating APlast_amp, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating APlast_amp, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating APlast_amp, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_CV, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_CV, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_log_slope, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_log_slope, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_log_slope_skip, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_log_slope_skip, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_semilog_slope, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_semilog_slope, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_values, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_values, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating ISI_values, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating adaptation_index, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating adaptation_index, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating adaptation_index2, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating adaptation_index2, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_first_last, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_first_last, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_first_last, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_first_second, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_first_second, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_first_second, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_second_last, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_second_last, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating amp_drop_second_last, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating doublet_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating doublet_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating doublet_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating fast_AHP, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating fast_AHP, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating fast_AHP, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating fast_AHP_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating fast_AHP_change, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_fifth_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_fifth_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_first_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_first_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_first_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_fourth_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_fourth_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_last_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_last_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_last_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_second_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_second_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_second_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_third_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_third_ISI, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_time_to_first_spike, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_time_to_first_spike, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating inv_time_to_first_spike, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating irregularity_index, An error occurred while computing the feature, feature is not found. Voltage never goes below or above threshold in spike detection.
#   warnings.warn(
# ...
# numprocs=1
# - running amplitude: 0.2 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: -0.1 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: -0.2 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: -0.15 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: -0.05 on model: ca1_pc_12 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_12 at: soma(0.5)
#
# - running amplitude: 0.05 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.15 on model: ca1_pc_12 at: soma(0.5)
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_12/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 294/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_12/
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.0, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: -0.15 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: -0.05 on model: ca1_pc_13 at: soma(0.5)- running amplitude: -0.1 on model: ca1_pc_13 at: soma(0.5)
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: -0.2 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: -0.25 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.15 on model: ca1_pc_13 at: soma(0.5)
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_13/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 294/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_13/
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 0.0, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: -0.25 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: -0.15 on model: ca1_pc_14 at: soma(0.5)- running amplitude: -0.2 on model: ca1_pc_14 at: soma(0.5)
#
# - running amplitude: -0.1 on model: ca1_pc_14 at: soma(0.5)- running amplitude: -0.05 on model: ca1_pc_14 at: soma(0.5)
#
# - running amplitude: 0.05 on model: ca1_pc_14 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.1 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.15 on model: ca1_pc_14 at: soma(0.5)
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_14/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): initburst_sahp.Step0.25, initburst_sahp_ssse.Step0.25, initburst_sahp_vb.Step0.25, min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 291/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_14/
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.0, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: 0.05 on model: ca1_pc_15 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_15 at: soma(0.5)
#
# - running amplitude: -0.25 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: -0.1 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: -0.2 on model: ca1_pc_15 at: soma(0.5)- running amplitude: -0.05 on model: ca1_pc_15 at: soma(0.5)
#
# - running amplitude: -0.15 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.15 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_15 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_15/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): initburst_sahp.Step0.25, initburst_sahp_ssse.Step0.25, initburst_sahp_vb.Step0.25, min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 291/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_15/
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 0.0, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: 0.15 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: -0.1 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: -0.25 on model: ca1_pc_16 at: soma(0.5)- running amplitude: -0.05 on model: ca1_pc_16 at: soma(0.5)- running amplitude: -0.2 on model: ca1_pc_16 at: soma(0.5)- running amplitude: 0.05 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_16 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_16 at: soma(0.5)
#
#
#
#
# - running amplitude: -0.15 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_16/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): initburst_sahp.Step0.25, initburst_sahp_ssse.Step0.25, initburst_sahp_vb.Step0.25, min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 291/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_16/
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 0.0, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: -0.1 on model: ca1_pc_17 at: soma(0.5)- running amplitude: -0.25 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: -0.2 on model: ca1_pc_17 at: soma(0.5)
#
# - running amplitude: 0.05 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: -0.05 on model: ca1_pc_17 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_17 at: soma(0.5)
#
# - running amplitude: -0.15 on model: ca1_pc_17 at: soma(0.5)- running amplitude: 0.15 on model: ca1_pc_17 at: soma(0.5)
#
# - running amplitude: 0.1 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_17/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 294/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_17/
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 0.0, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# - running amplitude: -0.2 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.15 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: -0.1 on model: ca1_pc_18 at: soma(0.5)- running amplitude: -0.15 on model: ca1_pc_18 at: soma(0.5)
#
# - running amplitude: -0.25 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: -0.05 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_18 at: soma(0.5)
#
# - running amplitude: 0.1 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# /home/tarluca/.local/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating min_AHP_values,
#   warnings.warn(
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/somaticfeat/ca1_pc_18/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# Features excluded (due to invalid values): initburst_sahp.Step0.25, initburst_sahp_ssse.Step0.25, initburst_sahp_vb.Step0.25, min_AHP_values.Step0.15, min_AHP_values.Step0.2, min_AHP_values.Step0.25
# Number of features succesfully evaluated: 291/297
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/results/somaticfeat/ca1_pc_18/

# %%
#pip install sciunit quantities efel scipy json2html neurom

# %%
#% matplotlib notebook
# %matplotlib inline
from json2html import *
import quantities
from quantities import mV, nA
import IPython
import json
import collections
import pkg_resources
import numpy

#import sciunit
#from hippounit import models
from hippounit import tests
from hippounit.utils_50Ra_major_nmda import ModelLoader_synapse_on_Passive_Spine, ModelLoader_synapse_on_Active_Spine
from hippounit.utils_50Ra_major_nmda import ModelLoader_Modellke, ModelLoader_synapse_on_Existing_Spine
#from hippounit import capabilities
#import matplotlib.pyplot as plt

from neuron import h
# Out:
# Invalid MIT-MAGIC-COOKIE-1 key

# %%
import hippounit
print(hippounit.__file__)
# Out:
# /home/tarluca/Modellke_story/hippounit_Spine_project_20221102/hippounit/hippounit/__init__.py

# %% [markdown]
# # Synapses arrive at dendritic shaft - Active F-factor

# %% [markdown]
# ## Instantiating the model

# %%
#all the outputs will be saved here. It will be an argument to the test.
"""Edit the line below"""
base_directory = '/mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/'

# path to mod files
"""Edit the line below"""
mod_files_path = "/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/mod_files/"

# user function path
"""Edit the line below"""
user_function_path = '/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/usr_fun_model_full_rework7.txt'

#Load cell model
model = ModelLoader_Modellke(mod_files_path = mod_files_path, user_function_path = user_function_path)

# path to hoc file
# the model must not display any GUI!!
"""Edit the line below"""
model.hocpath = "/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/load_model_na_inhomo_minimal_model_full_soma_f_fact_true_diam_active_spine_KA_fact_50Ra.hoc"
# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'soma'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'trunk'
model.TuftSecList_name = 'tuft'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'

model.BasalSecList_name = 'basal_dendrites'

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -70
model.celsius = 33

model.c_step_start = 0.000004
model.c_step_stop = 0.0000004
model.c_minmax = numpy.array([0.000004, 0.004])

# %% [markdown]
# ## PSP Attenuation Test

# %%
# Load target data
"""Edit the line below"""
with open('/home/tarluca/Modellke_story/hippounit_Spine_project_20221102/hippounit/target_features/feat_PSP_attenuation_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_attenuation_soma/dend_100_um</th><td>0.67037891837</td></tr><tr><th>std_attenuation_soma/dend_100_um</th><td>0.0745536001493</td></tr><tr><th>mean_attenuation_soma/dend_200_um</th><td>0.485024302539</td></tr><tr><th>std_attenuation_soma/dend_200_um</th><td>0.108372269307</td></tr><tr><th>mean_attenuation_soma/dend_300_um</th><td>0.282118043034</td></tr><tr><th>std_attenuation_soma/dend_300_um</th><td>0.0482703550105</td></tr></table>

# %%
#stimuli
import pkg_resources
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/PSP_attenuation_stim/stim_PSP_attenuation_test.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Instantiate the test class
test = tests.PSPAttenuationTest(config=config, observation=observation, num_of_dend_locations = 15, force_run=True, show_plot=True, save_all = True, base_directory=base_directory)

# Number of parallel processes
test.npool = 20

"""Edit the line below"""
f = open('/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/results_ca1_results/last.csv')
lines = []
for l in f.readlines():
    #print l.strip().split(',')
    lines.append(l.strip().split(','))
f.close()

for i in range(1, len(lines)):
    parameters = [float(j) for j in lines[i]]
    #lines[i].pop(0)
    parameters.pop(0)
    print(parameters)
    
    model.parameters = parameters
    # outputs will be saved in folders named like this:
    """Edit the line below"""
    model.name="ca1_pc_"+str(i)
    if numpy.isnan(parameters[0]):
        print('Parameters are nan')
        pass
    else:
        try:
            #Run the test 
            score = test.judge(model)
            #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
            score.summarize()

        except Exception as e:
            print('Model: ' + model.name + ' could not be run')
            print(e)
            pass
# Out:
# [-45.62129913381898, 0.015409599702098875, 0.16934641974325604, 0.102497419723226, 0.01715443774845717, 3.186132641811301e-06, 0.5652767116654946, -52.23667802503073, 0.00011082608622602389, 2.5294454453721573, 0.0005504949038343946, 0.004872936344012498, 0.08360930584022765, 4.477777340775202, 0.00027763058004307847, 1.9062470225446426, 3.090885414637565e-05, 0.00010916090173468279, -25.8501085422728, 8.658052647964135, 9.94749900407636]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0input at: dendrite[87](0.5) with weight: 0.0
#
#
#
#
# input at: dendrite[91](0.5) with weight: 0.0
#
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
#
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0input at: dendrite[55](0.5) with weight: 0.0
#
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[77](0.5) with weight: 0.0004654253359674197input at: dendrite[31](0.5) with weight: 0.0004653464906614145input at: dendrite[117](0.5) with weight: 0.0004656587870331948
#
#
# input at: dendrite[99](0.5) with weight: 0.0004655344838737411
# input at: dendrite[95](0.5) with weight: 0.00046552381088594077input at: dendrite[105](0.5) with weight: 0.0004655874648478311
#
# input at: dendrite[87](0.5) with weight: 0.00046550866408459input at: dendrite[91](0.5) with weight: 0.00046551782299767184
# input at: dendrite[102](0.5) with weight: 0.0004655687057010538
#
# input at: dendrite[101](0.5) with weight: 0.00046555198612700837input at: dendrite[129](0.5) with weight: 0.0004656941677657589
#
# input at: dendrite[103](0.5) with weight: 0.0004655626116364248input at: dendrite[55](0.5) with weight: 0.0004653713587971977
#
# input at: dendrite[109](0.5) with weight: 0.000465603468057042
# input at: dendrite[85](0.5) with weight: 0.00046549331201028966
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_1/
# [-46.040897240254466, 0.006201638265920286, 0.16643093941255963, 0.12015360279623795, 0.01855024051919542, 3.050877532413194e-06, 0.5778286617503535, -52.96672425021548, 0.00010857843534397874, 2.2582993666038007, 0.00048070376739039734, 0.007624772037544107, 0.08243437074055884, 3.9454122138331558, 0.0003270256222695575, 3.753661420335345, 3.310974041408122e-05, 5.6046432137755266e-05, -25.99234447253931, 7.932860925121936, 9.651211379950146]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0
#
#
#
#
# input at: dendrite[105](0.5) with weight: 0.0input at: dendrite[87](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[129](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
#
# input at: dendrite[109](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046535994619901653input at: dendrite[77](0.5) with weight: 0.00046545486085737813
# input at: dendrite[117](0.5) with weight: 0.0004657512382392343
#
# input at: dendrite[99](0.5) with weight: 0.0004655894633940416input at: dendrite[95](0.5) with weight: 0.0004655757631662469
# input at: dendrite[105](0.5) with weight: 0.0004656575502244662
#
# input at: dendrite[87](0.5) with weight: 0.00046555676174140736input at: dendrite[91](0.5) with weight: 0.0004655681655663873
# input at: dendrite[102](0.5) with weight: 0.00046563344127106983
#
# input at: dendrite[129](0.5) with weight: 0.00046580119082932826
# input at: dendrite[101](0.5) with weight: 0.0004656120554867212
# input at: dendrite[103](0.5) with weight: 0.0004656258458280745
# input at: dendrite[55](0.5) with weight: 0.000465389074365987
# input at: dendrite[109](0.5) with weight: 0.00046567815285782066
# input at: dendrite[85](0.5) with weight: 0.00046553783367776693
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_2/
# [-47.44867095267445, 0.011109187751335303, 0.1794770896087662, 0.09430168827952866, 0.01687426159838596, 2.8790117398617995e-06, 0.5638693408423257, -45.59460440980668, 0.000100903585922311, 3.240730801382151, 0.00021122552804335158, 0.005950463626715401, 0.08554225745832286, 4.365023991527042, 0.00043361320491048106, 2.962262445379956, 8.001383301793551e-05, 6.18058690231707e-06, -25.61354288150772, 13.255885822352512, 10.096218681617872]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0
#
#
# input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0
#
#
# input at: dendrite[87](0.5) with weight: 0.0
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0
#
# input at: dendrite[103](0.5) with weight: 0.0input at: dendrite[55](0.5) with weight: 0.0
#
#
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046499894841502316
# input at: dendrite[117](0.5) with weight: 0.00046461623280480126
# input at: dendrite[77](0.5) with weight: 0.0004649655702666036input at: dendrite[99](0.5) with weight: 0.00046485910252028206
#
# input at: dendrite[95](0.5) with weight: 0.00046487425706296927input at: dendrite[105](0.5) with weight: 0.0004647775902849693
# input at: dendrite[87](0.5) with weight: 0.00046489243215303266
# input at: dendrite[91](0.5) with weight: 0.0004648820376166527input at: dendrite[102](0.5) with weight: 0.00046480725710534214
#
#
# input at: dendrite[129](0.5) with weight: 0.0004645065640545049input at: dendrite[101](0.5) with weight: 0.0004648326889580077
#
# input at: dendrite[103](0.5) with weight: 0.00046481628684157735input at: dendrite[55](0.5) with weight: 0.00046499684448815705
#
# input at: dendrite[109](0.5) with weight: 0.00046474740178858586input at: dendrite[85](0.5) with weight: 0.00046490802384684446
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_3/
# [-45.78665331763355, 0.006522220083671663, 0.1655125678869768, 0.11596216295624726, 0.018166521011299116, 3.59566879568288e-06, 0.5731251075726675, -55.77711097242417, 0.00011012893493900798, 2.3382097234840606, 0.0005132650153760668, 0.00707995683802605, 0.08523082752272812, 4.282244864269837, 0.00030402102556902755, 3.501714968358538, 2.0410328329712233e-05, 6.908766164197318e-05, -26.055513361458345, 8.240243923944442, 9.964200579953241]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0
#
# input at: dendrite[105](0.5) with weight: 0.0
#
# input at: dendrite[87](0.5) with weight: 0.0
#
# input at: dendrite[91](0.5) with weight: 0.0
# input at: dendrite[102](0.5) with weight: 0.0
#
# input at: dendrite[129](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046552216246208155
# input at: dendrite[117](0.5) with weight: 0.00046605561858447173
# input at: dendrite[99](0.5) with weight: 0.00046581610895869284input at: dendrite[77](0.5) with weight: 0.0004656385527566724
#
# input at: dendrite[95](0.5) with weight: 0.0004657971032324476
# input at: dendrite[105](0.5) with weight: 0.0004659121257680119input at: dendrite[87](0.5) with weight: 0.00046577134806297007
#
# input at: dendrite[91](0.5) with weight: 0.00046578669762284305
# input at: dendrite[102](0.5) with weight: 0.0004658779017857235
# input at: dendrite[129](0.5) with weight: 0.0004661376592256225input at: dendrite[101](0.5) with weight: 0.000465847775884384
#
# input at: dendrite[103](0.5) with weight: 0.0004658671607429132
# input at: dendrite[55](0.5) with weight: 0.00046555633847293924
# input at: dendrite[109](0.5) with weight: 0.00046594247293029747input at: dendrite[85](0.5) with weight: 0.00046574623206268543
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_4/
# [-47.56754339778246, 0.0034569246944536284, 0.1763761994153427, 0.11384416219791055, 0.018057542479059635, 2.5709540929701745e-06, 0.565157000291921, -44.0638164995772, 0.00010630006750067032, 2.1550919517474574, 0.00032777968361675147, 0.0064049060207446475, 0.08311770940568883, 3.5295785276668465, 0.00019617309279755112, 2.321838524046095, 6.755879668492603e-05, 1.4278600621555496e-05, -25.856693746753017, 8.69833233460585, 9.450976236739242]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0
#
# input at: dendrite[95](0.5) with weight: 0.0
# input at: dendrite[99](0.5) with weight: 0.0
#
# input at: dendrite[105](0.5) with weight: 0.0
# input at: dendrite[87](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
#
# input at: dendrite[101](0.5) with weight: 0.0input at: dendrite[103](0.5) with weight: 0.0
#
# input at: dendrite[55](0.5) with weight: 0.0
# numprocs=1
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046525857559928663input at: dendrite[117](0.5) with weight: 0.00046509849302294696
#
# input at: dendrite[77](0.5) with weight: 0.0004652649750491346input at: dendrite[95](0.5) with weight: 0.00046523734827226315input at: dendrite[99](0.5) with weight: 0.0004652303259541423
#
#
# input at: dendrite[105](0.5) with weight: 0.0004651903944204244input at: dendrite[91](0.5) with weight: 0.00046524073479556517
# input at: dendrite[87](0.5) with weight: 0.0004652447658699464
#
# input at: dendrite[102](0.5) with weight: 0.00046520522680950407
# input at: dendrite[129](0.5) with weight: 0.0004650298935973624input at: dendrite[101](0.5) with weight: 0.0004652175911484341input at: dendrite[103](0.5) with weight: 0.0004652095747650781
#
#
# input at: dendrite[55](0.5) with weight: 0.0004652662546874551
# input at: dendrite[109](0.5) with weight: 0.0004651742680860736input at: dendrite[85](0.5) with weight: 0.00046525012258465223
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_5/
# [-47.41373018487568, 0.008254620649759174, 0.19902108579099106, 0.03331133101820424, 0.01080902054018693, 3.980739602781064e-06, 0.5625024134131904, -55.14968446172642, 0.00011523357069797892, 4.050572617070594, 0.0006181114345366373, 0.003624544943032839, 0.07396905858107695, 3.938334988895222, 0.00031111423951891694, 2.5878686058319946, 3.9582346139622276e-05, 5.047202517142653e-05, -24.615106873325523, 10.539982881654002, 8.86059670041674]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0
#
#
# input at: dendrite[99](0.5) with weight: 0.0
# input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0
#
# input at: dendrite[87](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[101](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
#
#
# input at: dendrite[103](0.5) with weight: 0.0input at: dendrite[55](0.5) with weight: 0.0
#
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.0004650657067653169input at: dendrite[99](0.5) with weight: 0.0004651295279613038
# input at: dendrite[117](0.5) with weight: 0.0004651585090336217
# input at: dendrite[77](0.5) with weight: 0.00046509460240656196
#
# input at: dendrite[95](0.5) with weight: 0.00046512656923145625input at: dendrite[105](0.5) with weight: 0.00046514510862188393
#
# input at: dendrite[91](0.5) with weight: 0.0004651248253258958input at: dendrite[87](0.5) with weight: 0.00046512190947111927
#
# input at: dendrite[102](0.5) with weight: 0.00046513941901340583
# input at: dendrite[129](0.5) with weight: 0.00046515946115288724
# input at: dendrite[101](0.5) with weight: 0.00046513435916880973
# input at: dendrite[103](0.5) with weight: 0.000465137217761011
# input at: dendrite[55](0.5) with weight: 0.000465077233921837
# input at: dendrite[109](0.5) with weight: 0.0004651491232026999input at: dendrite[85](0.5) with weight: 0.0004651168790776515
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_6/
# [-47.31451672012254, 0.012328554000674945, 0.1763659214563141, 0.09725443755483688, 0.017251771349790872, 3.880331262377635e-06, 0.5611571766403177, -52.598406221527824, 0.00010095033740219401, 2.440170802041241, 0.00011272549265684803, 0.0060279416574691306, 0.08105832085105877, 3.8219611316312587, 0.0003741349109792469, 1.651630089516989, 6.604035002586476e-05, 1.9816455880956684e-05, -25.645475638898212, 9.509148681749004, 9.494355706082823]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0
# input at: dendrite[87](0.5) with weight: 0.0
#
#
#
#
#
# input at: dendrite[91](0.5) with weight: 0.0
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0
#
# input at: dendrite[103](0.5) with weight: 0.0input at: dendrite[55](0.5) with weight: 0.0
#
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046535151925618414input at: dendrite[95](0.5) with weight: 0.00046534401381030524
# input at: dendrite[117](0.5) with weight: 0.00046523437321256504input at: dendrite[99](0.5) with weight: 0.00046533879107685044input at: dendrite[77](0.5) with weight: 0.00046536286089052085
#
#
#
# input at: dendrite[105](0.5) with weight: 0.000465308380431331
# input at: dendrite[87](0.5) with weight: 0.0004653494700298205input at: dendrite[102](0.5) with weight: 0.00046531974395595365
# input at: dendrite[91](0.5) with weight: 0.000465346513401486
# input at: dendrite[129](0.5) with weight: 0.00046518013893050305
#
# input at: dendrite[103](0.5) with weight: 0.00046532322955345054input at: dendrite[101](0.5) with weight: 0.00046532922581149586
#
# input at: dendrite[55](0.5) with weight: 0.00046536032175163846
# input at: dendrite[109](0.5) with weight: 0.0004652955016760961
# input at: dendrite[85](0.5) with weight: 0.0004653532992755614
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_7/
# [-45.70061506784235, 0.003570403096842624, 0.16807335532098958, 0.1009286818175892, 0.017525620849071916, 4.585538195703631e-06, 0.5629100538686723, -59.68928291602768, 0.00010454548341151828, 2.3367783718576485, 0.0002519193807863983, 0.003574673600591661, 0.08638069491828596, 4.395065717151833, 0.0002465051651731948, 4.347864023762802, 1.881879876717133e-05, 6.953485849829401e-05, -25.836868420675895, 8.470751052424282, 10.13828126032654]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0
#
#
# input at: dendrite[95](0.5) with weight: 0.0
# input at: dendrite[105](0.5) with weight: 0.0
#
# input at: dendrite[87](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0input at: dendrite[101](0.5) with weight: 0.0
#
#
# input at: dendrite[55](0.5) with weight: 0.0input at: dendrite[103](0.5) with weight: 0.0
#
# input at: dendrite[85](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046517061790701244input at: dendrite[117](0.5) with weight: 0.00046575825476260867
# input at: dendrite[77](0.5) with weight: 0.0004652933668391983
#
# input at: dendrite[99](0.5) with weight: 0.0004654840533900243input at: dendrite[95](0.5) with weight: 0.000465462731171261
#
# input at: dendrite[105](0.5) with weight: 0.00046559240955540106input at: dendrite[87](0.5) with weight: 0.0004654344966747113
#
# input at: dendrite[91](0.5) with weight: 0.00046545119303191687input at: dendrite[102](0.5) with weight: 0.0004655536590345767
#
# input at: dendrite[129](0.5) with weight: 0.00046585904750693697
# input at: dendrite[101](0.5) with weight: 0.0004655198176273974
# input at: dendrite[103](0.5) with weight: 0.00046554182130094114
# input at: dendrite[55](0.5) with weight: 0.00046520630770863447
# input at: dendrite[109](0.5) with weight: 0.0004656268169134645
# input at: dendrite[85](0.5) with weight: 0.0004654074889341265
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_8/
# [-46.80183513210604, 0.0076671224287107875, 0.1745835157567751, 0.11549981335981602, 0.01839013652864369, 3.2988317696801607e-06, 0.5792168041642852, -54.92442839624785, 0.00010600340036731842, 2.579504257220232, 0.00043000170998462036, 0.002985333430103456, 0.08725467197795292, 4.297442393609947, 9.299007440363277e-05, 4.086861620147421, 3.110920991678848e-05, 4.4522458947423534e-05, -25.8564313498149, 10.813283404910708, 10.120429902972663]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0
#
#
# input at: dendrite[99](0.5) with weight: 0.0
# input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0input at: dendrite[87](0.5) with weight: 0.0
#
#
# input at: dendrite[91](0.5) with weight: 0.0
# input at: dendrite[102](0.5) with weight: 0.0
# input at: dendrite[129](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0input at: dendrite[109](0.5) with weight: 0.0
#
#
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046523663829677687input at: dendrite[117](0.5) with weight: 0.00046566650420551273
#
# input at: dendrite[77](0.5) with weight: 0.0004653364139196147input at: dendrite[99](0.5) with weight: 0.00046548130720705066
#
# input at: dendrite[95](0.5) with weight: 0.0004654660465791998
# input at: dendrite[105](0.5) with weight: 0.0004655577422519775input at: dendrite[87](0.5) with weight: 0.00046544524645941753
#
# input at: dendrite[91](0.5) with weight: 0.0004654576611946517
# input at: dendrite[102](0.5) with weight: 0.0004655305762569284
# input at: dendrite[129](0.5) with weight: 0.0004657278079674541
# input at: dendrite[101](0.5) with weight: 0.0004655066307455068
# input at: dendrite[103](0.5) with weight: 0.0004655221405047653input at: dendrite[55](0.5) with weight: 0.0004652669268350789
#
# input at: dendrite[109](0.5) with weight: 0.00046558117416934275
# input at: dendrite[85](0.5) with weight: 0.0004654248263312522
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_9/
# [-47.046727363856604, 0.009142393231027515, 0.1734564459234941, 0.09038476927965003, 0.01760626754851751, 3.5111827942761145e-06, 0.5637715311977243, -52.58392742050847, 0.0001023862466954727, 2.650293496390263, 0.00012941406042032142, 0.00754367054371495, 0.08183910018142451, 3.9739114505467312, 0.000423559552187225, 2.247546439768558, 5.705436152661179e-05, 7.9192533919979e-06, -25.77133920358794, 10.557520684494044, 9.817720235162609]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0
#
# input at: dendrite[105](0.5) with weight: 0.0
#
# input at: dendrite[95](0.5) with weight: 0.0
#
# input at: dendrite[87](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
#
# input at: dendrite[101](0.5) with weight: 0.0input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
#
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046530974211758696input at: dendrite[77](0.5) with weight: 0.00046534420929861974input at: dendrite[117](0.5) with weight: 0.00046533494242070764input at: dendrite[99](0.5) with weight: 0.00046536379775795605
#
#
#
# input at: dendrite[105](0.5) with weight: 0.00046536125172479874input at: dendrite[95](0.5) with weight: 0.00046536366692115664
#
# input at: dendrite[87](0.5) with weight: 0.00046536231073707326input at: dendrite[91](0.5) with weight: 0.00046536333083867633
#
# input at: dendrite[102](0.5) with weight: 0.00046536257092007953input at: dendrite[129](0.5) with weight: 0.00046531144634138355
# input at: dendrite[101](0.5) with weight: 0.00046536335685890847
#
# input at: dendrite[55](0.5) with weight: 0.0004653241933056464
# input at: dendrite[103](0.5) with weight: 0.0004653629962935369
# input at: dendrite[109](0.5) with weight: 0.0004653578074480901input at: dendrite[85](0.5) with weight: 0.0004653598841386311
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_10/
# [-46.09618053045715, 0.007775097860383771, 0.16794499539035, 0.11189937512688124, 0.0183234075541897, 2.269642309727379e-06, 0.5907587147759761, -48.80236588926401, 0.00010889338624677877, 2.4313241749123637, 0.0005172129520601723, 0.006652478575514465, 0.08489938140028669, 4.285605165703842, 0.00036595420298276014, 1.3189755297626504, 2.720127640968989e-05, 6.863908662232526e-05, -26.00124057672013, 9.60837790581702, 10.218413562564086]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0
#
#
# input at: dendrite[99](0.5) with weight: 0.0
#
# input at: dendrite[105](0.5) with weight: 0.0input at: dendrite[87](0.5) with weight: 0.0
#
# input at: dendrite[91](0.5) with weight: 0.0input at: dendrite[102](0.5) with weight: 0.0
#
# input at: dendrite[129](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[99](0.5) with weight: 0.000465629027857172input at: dendrite[77](0.5) with weight: 0.0004654841769930415input at: dendrite[31](0.5) with weight: 0.00046538563340444534input at: dendrite[117](0.5) with weight: 0.00046581752182079224input at: dendrite[95](0.5) with weight: 0.00046561381241724305
#
#
#
#
# input at: dendrite[87](0.5) with weight: 0.00046559300838883844input at: dendrite[105](0.5) with weight: 0.0004657055307570488
#
# input at: dendrite[91](0.5) with weight: 0.0004656054417570898
# input at: dendrite[102](0.5) with weight: 0.0004656783045278773input at: dendrite[101](0.5) with weight: 0.00046565429240359534input at: dendrite[129](0.5) with weight: 0.0004658803331938503input at: dendrite[103](0.5) with weight: 0.0004656697449301689
#
#
#
# input at: dendrite[55](0.5) with weight: 0.00046541554045228785
# input at: dendrite[109](0.5) with weight: 0.00046572946402173863input at: dendrite[85](0.5) with weight: 0.0004655725540301744
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_11/
# [-46.43098921885185, 0.014742147894969953, 0.18316433424759593, 0.059066000395619205, 0.013030258748267933, 3.2672584962106302e-06, 0.5573870454663593, -50.12630565351253, 0.00011472328707127583, 3.1806723735118707, 0.00044112245094793417, 0.0030303792466399933, 0.07808914228801972, 4.2452433171562465, 0.00047148701481152503, 2.0132028363310535, 5.895267277175964e-05, 3.35656479521197e-05, -25.13216844278952, 9.36964860530109, 8.446839225181549]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0
# input at: dendrite[87](0.5) with weight: 0.0
#
#
#
#
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[129](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.0004650307904730859input at: dendrite[117](0.5) with weight: 0.00046489969994607295input at: dendrite[77](0.5) with weight: 0.0004650304952691044
#
#
# input at: dendrite[99](0.5) with weight: 0.00046499994475816846input at: dendrite[95](0.5) with weight: 0.00046500558011362125
# input at: dendrite[105](0.5) with weight: 0.0004649693981471017
#
# input at: dendrite[91](0.5) with weight: 0.00046500832711310195input at: dendrite[87](0.5) with weight: 0.00046501161161369695
# input at: dendrite[102](0.5) with weight: 0.0004649805395581882
#
# input at: dendrite[129](0.5) with weight: 0.0004648463262530465
# input at: dendrite[101](0.5) with weight: 0.0004649899118941388input at: dendrite[103](0.5) with weight: 0.0004649835798053057
#
# input at: dendrite[55](0.5) with weight: 0.00046503580204868304
# input at: dendrite[85](0.5) with weight: 0.00046501612437351144
# input at: dendrite[109](0.5) with weight: 0.0004649572568923136
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_12/
# [-47.72337441637088, 0.01140172013401096, 0.1786616587257201, 0.11053354636193662, 0.018195328014434794, 4.133768197516964e-06, 0.5582806899906827, -55.19770644190086, 0.00010200745484185201, 2.3515157971690615, 0.0001877328584298627, 0.008177991377281032, 0.08260836312643614, 3.6997573520936617, 0.0005811457032595042, 3.69310750687799, 5.1266274824495e-05, 1.1531756152623465e-05, -25.80099593321027, 9.724705579722128, 9.756717519433426]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0
#
# input at: dendrite[105](0.5) with weight: 0.0
#
#
#
# input at: dendrite[87](0.5) with weight: 0.0
# input at: dendrite[91](0.5) with weight: 0.0
# input at: dendrite[129](0.5) with weight: 0.0input at: dendrite[102](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0
#
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[117](0.5) with weight: 0.0004653683478538592input at: dendrite[31](0.5) with weight: 0.0004652365141511716
# input at: dendrite[77](0.5) with weight: 0.0004652898290805412
#
# input at: dendrite[99](0.5) with weight: 0.00046534346571673905input at: dendrite[105](0.5) with weight: 0.00046536137335806454
#
# input at: dendrite[95](0.5) with weight: 0.0004653393544213139input at: dendrite[91](0.5) with weight: 0.00046533688612411257
# input at: dendrite[102](0.5) with weight: 0.00046535536509942886input at: dendrite[87](0.5) with weight: 0.0004653328241211129
#
#
# input at: dendrite[129](0.5) with weight: 0.00046536535055377473input at: dendrite[101](0.5) with weight: 0.0004653497522686749
#
# input at: dendrite[103](0.5) with weight: 0.0004653535319323266
# input at: dendrite[55](0.5) with weight: 0.00046525560209907907
# input at: dendrite[109](0.5) with weight: 0.0004653646731357602input at: dendrite[85](0.5) with weight: 0.0004653255452719076
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_13/
# [-43.42167238220148, 0.016646971548319695, 0.14591877428057348, 0.06463425378544702, 0.01875919428020742, 2.054255298301458e-06, 0.5601124207111279, -33.586267387792006, 0.00010632846319659363, 4.3185111438640345, 0.00010109983299561467, 0.005522530454558956, 0.07879349712156349, 3.64979499739897, 0.0006147823453281284, 2.460146131889926, 6.195044945251061e-05, 4.143856990551319e-05, -26.59034157789421, 21.990027193454814, 13.109736787763111]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0
#
#
#
# input at: dendrite[95](0.5) with weight: 0.0
# input at: dendrite[105](0.5) with weight: 0.0
# input at: dendrite[87](0.5) with weight: 0.0
# input at: dendrite[91](0.5) with weight: 0.0
# input at: dendrite[102](0.5) with weight: 0.0
# input at: dendrite[129](0.5) with weight: 0.0input at: dendrite[101](0.5) with weight: 0.0
#
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0input at: dendrite[85](0.5) with weight: 0.0
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[99](0.5) with weight: 0.0004650614114839822input at: dendrite[77](0.5) with weight: 0.0004651893105035199input at: dendrite[31](0.5) with weight: 0.0004652327280528898input at: dendrite[117](0.5) with weight: 0.00046478912819634857
#
#
#
# input at: dendrite[95](0.5) with weight: 0.0004650791756790241
# input at: dendrite[105](0.5) with weight: 0.00046496688820778513
# input at: dendrite[87](0.5) with weight: 0.00046510071312346217
# input at: dendrite[91](0.5) with weight: 0.0004650883473316019input at: dendrite[102](0.5) with weight: 0.00046500104553490315
#
# input at: dendrite[101](0.5) with weight: 0.0004650305917606625input at: dendrite[129](0.5) with weight: 0.0004646729234491388
#
# input at: dendrite[103](0.5) with weight: 0.00046501144728276674
# input at: dendrite[55](0.5) with weight: 0.00046522851574279904
# input at: dendrite[109](0.5) with weight: 0.0004649329617049043input at: dendrite[85](0.5) with weight: 0.00046511940636931786
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_14/
# [-47.36412077672516, 0.01845684128512603, 0.17814464809204775, 0.09801973465776564, 0.017491765167116143, 2.8564641317033475e-06, 0.5638244000844898, -44.86941055893655, 0.00010186616858264085, 2.9616705980485785, 0.000173755029991464, 0.0038641960216311494, 0.08623571231736615, 4.083658810896312, 0.0005914058091424999, 2.4186742298275843, 8.124438215308016e-05, 1.3030823862865115e-05, -25.70341504115122, 12.767909379901798, 10.04426956604328]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# ...
# input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0
#
#
# input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0
# input at: dendrite[105](0.5) with weight: 0.0
#
# input at: dendrite[87](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[129](0.5) with weight: 0.0input at: dendrite[102](0.5) with weight: 0.0
#
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.0004652251658187979input at: dendrite[77](0.5) with weight: 0.0004651838360832944
# input at: dendrite[117](0.5) with weight: 0.0004647914602777963
# input at: dendrite[99](0.5) with weight: 0.00046506010805203243
#
# input at: dendrite[95](0.5) with weight: 0.0004650774288867404input at: dendrite[105](0.5) with weight: 0.00046496776544829426
# input at: dendrite[87](0.5) with weight: 0.0004650983539138697
#
# input at: dendrite[91](0.5) with weight: 0.0004650863557728465
# input at: dendrite[102](0.5) with weight: 0.0004650011763179876input at: dendrite[129](0.5) with weight: 0.0004646750079209781
#
# input at: dendrite[101](0.5) with weight: 0.00046503002271881984
# input at: dendrite[103](0.5) with weight: 0.0004650113276264031
# input at: dendrite[55](0.5) with weight: 0.00046522139460431465
# input at: dendrite[85](0.5) with weight: 0.0004651164472804032
# input at: dendrite[109](0.5) with weight: 0.0004649343198626905
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_16/
# [-45.25263563551992, 0.011011319765683439, 0.16542040716523546, 0.09696664824745947, 0.017200828644599115, 4.7074021567158434e-06, 0.5625747563975313, -60.39090358552191, 0.0001072903796942765, 2.534787218557705, 0.00017497074544706268, 0.006380469896373111, 0.08537821611193513, 4.576642929336708, 0.00033700176463888543, 2.43049620564932, 1.1775537260123656e-05, 8.17581526201146e-05, -25.923705342390356, 9.26135375322112, 10.27180909931623]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0
# input at: dendrite[117](0.5) with weight: 0.0
# input at: dendrite[77](0.5) with weight: 0.0
# input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0
#
# input at: dendrite[87](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0
# input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
#
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[117](0.5) with weight: 0.00046587971201935547input at: dendrite[77](0.5) with weight: 0.0004653318040794813input at: dendrite[31](0.5) with weight: 0.00046519489659744423input at: dendrite[95](0.5) with weight: 0.0004655260408272397
#
# input at: dendrite[99](0.5) with weight: 0.0004655510105960433
#
# input at: dendrite[105](0.5) with weight: 0.000465678513531284
#
# input at: dendrite[87](0.5) with weight: 0.0004654932455563918
# input at: dendrite[91](0.5) with weight: 0.0004655125883691081
# input at: dendrite[102](0.5) with weight: 0.0004656328433182143
# input at: dendrite[129](0.5) with weight: 0.0004660039035665778
# input at: dendrite[101](0.5) with weight: 0.0004655930325093838
# input at: dendrite[103](0.5) with weight: 0.0004656189146501128
# input at: dendrite[55](0.5) with weight: 0.00046523392121086005
# input at: dendrite[85](0.5) with weight: 0.0004654621274649653
# input at: dendrite[109](0.5) with weight: 0.00046571971478859774
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_17/
# [-47.04232285356018, 0.014448704300753238, 0.1759691587314087, 0.09748669054176126, 0.017524984612970376, 3.4947576081841974e-06, 0.5681850997515842, -51.86731303825768, 0.00010042575977660592, 2.8417743946313694, 0.00014034236533534363, 0.003817239362762621, 0.08691578782966701, 4.352097640325149, 0.0004892459145636438, 4.031285327033501, 6.680120400962877e-05, 4.006848484284392e-06, -25.69002193367114, 12.037049953659809, 9.954981527084161]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0
#
#
#
#
# input at: dendrite[105](0.5) with weight: 0.0
# input at: dendrite[87](0.5) with weight: 0.0input at: dendrite[91](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0
# input at: dendrite[129](0.5) with weight: 0.0
# input at: dendrite[101](0.5) with weight: 0.0input at: dendrite[103](0.5) with weight: 0.0
#
# input at: dendrite[55](0.5) with weight: 0.0input at: dendrite[109](0.5) with weight: 0.0
#
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.0004650948420675414input at: dendrite[117](0.5) with weight: 0.0004649770217158497input at: dendrite[77](0.5) with weight: 0.00046510586351702796input at: dendrite[99](0.5) with weight: 0.0004650811705084128
#
#
#
# input at: dendrite[95](0.5) with weight: 0.00046508631067471867
# input at: dendrite[87](0.5) with weight: 0.0004650917638119183input at: dendrite[105](0.5) with weight: 0.0004650513739490975
# input at: dendrite[91](0.5) with weight: 0.0004650887878167299
#
# input at: dendrite[102](0.5) with weight: 0.00046506246916591654
# input at: dendrite[129](0.5) with weight: 0.0004649234664454363input at: dendrite[101](0.5) with weight: 0.0004650717894034132
#
# input at: dendrite[103](0.5) with weight: 0.00046506592357786666input at: dendrite[55](0.5) with weight: 0.00046510366144020103
#
# input at: dendrite[109](0.5) with weight: 0.00046503846029049314input at: dendrite[85](0.5) with weight: 0.0004650956745465719
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_18/
# [-46.334610767400285, 0.007645056463057165, 0.16605117797830463, 0.11728809914299926, 0.018910001978398722, 3.458183634000247e-06, 0.5823047224871882, -54.97575597616935, 0.00010914212336452612, 2.4258871033370135, 0.0004784321151919786, 0.0073177215083622404, 0.08530316004083632, 4.300832767935444, 0.0006083125778196826, 0.752198878890235, 2.341805877809951e-05, 5.199033799174357e-05, -26.138874354498995, 9.108443778727151, 9.849452842082997]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[99](0.5) with weight: 0.0
#
#
#
# input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0
# input at: dendrite[87](0.5) with weight: 0.0
#
# input at: dendrite[91](0.5) with weight: 0.0
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
#
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0
# input at: dendrite[55](0.5) with weight: 0.0
# input at: dendrite[109](0.5) with weight: 0.0input at: dendrite[85](0.5) with weight: 0.0
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046544734064120596
# input at: dendrite[117](0.5) with weight: 0.00046599335374955216
# input at: dendrite[77](0.5) with weight: 0.00046556650119516344input at: dendrite[99](0.5) with weight: 0.0004657478055233239
#
# input at: dendrite[95](0.5) with weight: 0.0004657283685387386input at: dendrite[105](0.5) with weight: 0.0004658457144359494
#
# input at: dendrite[91](0.5) with weight: 0.000465717731917434input at: dendrite[87](0.5) with weight: 0.00046570206362822174
#
# input at: dendrite[102](0.5) with weight: 0.0004658108798389551
# input at: dendrite[129](0.5) with weight: 0.00046607794222953817
# input at: dendrite[101](0.5) with weight: 0.0004657801749238252input at: dendrite[103](0.5) with weight: 0.00046580000690598803
# input at: dendrite[55](0.5) with weight: 0.00046548231272116626
#
# input at: dendrite[109](0.5) with weight: 0.00046587681151616546input at: dendrite[85](0.5) with weight: 0.000465676432954318
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_19/
# [-44.779863188158615, 0.012384064972257365, 0.1701027551021645, 0.20732005736865539, 0.02090060009340788, 3.3119553188343e-06, 0.5595059630220126, -49.32144104834312, 0.00010964756879231327, 3.902440336394697, 0.0002406899967913593, 0.009182574915443794, 0.09208521545202661, 4.65782708909162, 0.0005077990775711956, 1.8251002285794327, 6.482906470567902e-05, 1.1692286846070997e-05, -26.344052889019622, 14.91562730499473, 9.308531296760517]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[117]', 0.5): 278.33171734906966, ('dendrite[77]', 0.5): 100.22118306272861, ('dendrite[99]', 0.5): 181.69452417270386, ('dendrite[95]', 0.5): 171.4537639215934, ('dendrite[105]', 0.5): 222.9376476900447, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[102]', 0.5): 215.32249997419848, ('dendrite[129]', 0.5): 320.6552047153468, ('dendrite[101]', 0.5): 199.3211605489655, ('dendrite[103]', 0.5): 222.40356073341383, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[85]', 0.5): 147.38275623716865}
# input at: dendrite[99](0.5) with weight: 0.0input at: dendrite[95](0.5) with weight: 0.0input at: dendrite[117](0.5) with weight: 0.0input at: dendrite[31](0.5) with weight: 0.0input at: dendrite[105](0.5) with weight: 0.0input at: dendrite[77](0.5) with weight: 0.0
#
#
#
#
#
# input at: dendrite[91](0.5) with weight: 0.0input at: dendrite[87](0.5) with weight: 0.0
#
# input at: dendrite[102](0.5) with weight: 0.0input at: dendrite[129](0.5) with weight: 0.0
#
# input at: dendrite[101](0.5) with weight: 0.0
# input at: dendrite[103](0.5) with weight: 0.0input at: dendrite[55](0.5) with weight: 0.0
#
# input at: dendrite[109](0.5) with weight: 0.0
# input at: dendrite[85](0.5) with weight: 0.0
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# input at: dendrite[31](0.5) with weight: 0.00046500131056818504input at: dendrite[117](0.5) with weight: 0.0004650103592706527
#
# input at: dendrite[77](0.5) with weight: 0.0004650419905345691input at: dendrite[99](0.5) with weight: 0.0004650630437658923
#
# input at: dendrite[95](0.5) with weight: 0.00046506390086694955
# input at: dendrite[105](0.5) with weight: 0.0004650537127240785input at: dendrite[87](0.5) with weight: 0.00046506314683496085
#
# input at: dendrite[91](0.5) with weight: 0.0004650639446698351
# input at: dendrite[102](0.5) with weight: 0.0004650577656631918
# input at: dendrite[129](0.5) with weight: 0.00046497076254513857input at: dendrite[101](0.5) with weight: 0.00046506057571439147
#
# input at: dendrite[103](0.5) with weight: 0.0004650588778267902input at: dendrite[55](0.5) with weight: 0.0004650177995116767
#
# input at: dendrite[109](0.5) with weight: 0.00046504752737702487input at: dendrite[85](0.5) with weight: 0.0004650606680806639
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/PSP_attenuation/ca1_pc_20/

# %%
# Load target data
"""Edit the line below"""
with open('/home/tarluca/Modellke_story/hippounit_Spine_project_20221102/hippounit/target_features/depol_block_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_Ith</th><td>0.6 nA</td></tr><tr><th>Ith_std</th><td>0.3 nA</td></tr><tr><th>mean_Veq</th><td>-40.1 mV</td></tr><tr><th>Veq_std</th><td>3.4 mV</td></tr></table>

# %%
# Instantiate the test class
test = tests.DepolarizationBlockTest(observation=observation, force_run=True, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 20

"""Edit the line below"""
f = open('/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/results_ca1_results/last.csv')
lines = []
for l in f.readlines():
    #print l.strip().split(',')
    lines.append(l.strip().split(','))
f.close()

for i in range(1, len(lines)):
    parameters = [float(j) for j in lines[i]]
    #lines[i].pop(0)
    parameters.pop(0)
    print(parameters)
    
    model.parameters = parameters
    # outputs will be saved in folders named like this:
    """Edit the line below"""
    model.name="ca1_pc_"+str(i)
    if numpy.isnan(parameters[0]):
        print('Parameters are nan')
        pass
    else:
        try:
            #Run the test 
            score = test.judge(model)
            #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
            score.summarize()

        except Exception as e:
            print('Model: ' + model.name + ' could not be run')
            print(e)
            pass
# Out:
# [-45.62129913381898, 0.015409599702098875, 0.16934641974325604, 0.102497419723226, 0.01715443774845717, 3.186132641811301e-06, 0.5652767116654946, -52.23667802503073, 0.00011082608622602389, 2.5294454453721573, 0.0005504949038343946, 0.004872936344012498, 0.08360930584022765, 4.477777340775202, 0.00027763058004307847, 1.9062470225446426, 3.090885414637565e-05, 0.00010916090173468279, -25.8501085422728, 8.658052647964135, 9.94749900407636]
# - running amplitude: 0.35000000000000003 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_1 at: soma(0.5)
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.30000000000000004 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.75 on model: ca1_pc_1 at: soma(0.5)
#
# - running amplitude: 0.1 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.25 on model: ca1_pc_1 at: soma(0.5)
#
# - running amplitude: 0.9 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.8500000000000001 on model: ca1_pc_1 at: soma(0.5)
#
# - running amplitude: 0.8 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 1.3 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 1.55 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_1 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_1/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_1/
# The model did not enter depolarization block.
# [-46.040897240254466, 0.006201638265920286, 0.16643093941255963, 0.12015360279623795, 0.01855024051919542, 3.050877532413194e-06, 0.5778286617503535, -52.96672425021548, 0.00010857843534397874, 2.2582993666038007, 0.00048070376739039734, 0.007624772037544107, 0.08243437074055884, 3.9454122138331558, 0.0003270256222695575, 3.753661420335345, 3.310974041408122e-05, 5.6046432137755266e-05, -25.99234447253931, 7.932860925121936, 9.651211379950146]
# - running amplitude: 0.15000000000000002 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.4 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_2 at: soma(0.5)
#
#
# - running amplitude: 0.05 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.25 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_2 at: soma(0.5)
#
# - running amplitude: 0.1 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_2 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.65 on model: ca1_pc_2 at: soma(0.5)
#
# - running amplitude: 0.9 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.9500000000000001 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.8 on model: ca1_pc_2 at: soma(0.5)
#
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_2 at: soma(0.5)numprocs=1
#
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 1.1500000000000001 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_2/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_2/
# The model did not enter depolarization block.
# [-47.44867095267445, 0.011109187751335303, 0.1794770896087662, 0.09430168827952866, 0.01687426159838596, 2.8790117398617995e-06, 0.5638693408423257, -45.59460440980668, 0.000100903585922311, 3.240730801382151, 0.00021122552804335158, 0.005950463626715401, 0.08554225745832286, 4.365023991527042, 0.00043361320491048106, 2.962262445379956, 8.001383301793551e-05, 6.18058690231707e-06, -25.61354288150772, 13.255885822352512, 10.096218681617872]
# - running amplitude: 0.30000000000000004 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_3 at: soma(0.5)
#
#
# - running amplitude: 0.25 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.05 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.45 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_3 at: soma(0.5)
#
#
# - running amplitude: 0.35000000000000003 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.8500000000000001 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.8 on model: ca1_pc_3 at: soma(0.5)
#
#
# - running amplitude: 0.9500000000000001 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.0 on model: ca1_pc_3 at: soma(0.5)numprocs=1
# numprocs=1
#
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 1.1 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 1.1500000000000001 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 1.4500000000000002 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_3 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_3/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.8 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.8500000000000001 nA
# Veq (the equilibrium value during the depolarization block): -39.30698346195373 mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_3/
# According to the experiment I_maxNumAP and I_below_depol_block should be equal. If they are not equal a penalty is applied (200 * the difference between them in nA).
# [-45.78665331763355, 0.006522220083671663, 0.1655125678869768, 0.11596216295624726, 0.018166521011299116, 3.59566879568288e-06, 0.5731251075726675, -55.77711097242417, 0.00011012893493900798, 2.3382097234840606, 0.0005132650153760668, 0.00707995683802605, 0.08523082752272812, 4.282244864269837, 0.00030402102556902755, 3.501714968358538, 2.0410328329712233e-05, 6.908766164197318e-05, -26.055513361458345, 8.240243923944442, 9.964200579953241]
# - running amplitude: 0.15000000000000002 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_4 at: soma(0.5)numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
#
# - running amplitude: 0.30000000000000004 on model: ca1_pc_4 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_4 at: soma(0.5)- running amplitude: 0.05 on model: ca1_pc_4 at: soma(0.5)
#
#
# - running amplitude: 0.25 on model: ca1_pc_4 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_4 at: soma(0.5)
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_4 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_4 at: soma(0.5)
#
# - running amplitude: 0.8 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.0 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 1.05 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 1.35 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 1.3 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_4/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_4/
# The model did not enter depolarization block.
# [-47.56754339778246, 0.0034569246944536284, 0.1763761994153427, 0.11384416219791055, 0.018057542479059635, 2.5709540929701745e-06, 0.565157000291921, -44.0638164995772, 0.00010630006750067032, 2.1550919517474574, 0.00032777968361675147, 0.0064049060207446475, 0.08311770940568883, 3.5295785276668465, 0.00019617309279755112, 2.321838524046095, 6.755879668492603e-05, 1.4278600621555496e-05, -25.856693746753017, 8.69833233460585, 9.450976236739242]
# - running amplitude: 0.6000000000000001 on model: ca1_pc_5 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_5 at: soma(0.5)
#
# - running amplitude: 0.05 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.25 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_5 at: soma(0.5)- running amplitude: 0.45 on model: ca1_pc_5 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_5 at: soma(0.5)
#
#
# - running amplitude: 0.75 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_5 at: soma(0.5)- running amplitude: 0.9500000000000001 on model: ca1_pc_5 at: soma(0.5)
#
# - running amplitude: 0.9 on model: ca1_pc_5 at: soma(0.5)- running amplitude: 0.8 on model: ca1_pc_5 at: soma(0.5)
#
# - running amplitude: 1.0 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 1.2000000000000002 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_5/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.8 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.8500000000000001 nA
# Veq (the equilibrium value during the depolarization block): -39.25650927053384 mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_5/
# According to the experiment I_maxNumAP and I_below_depol_block should be equal. If they are not equal a penalty is applied (200 * the difference between them in nA).
# [-47.41373018487568, 0.008254620649759174, 0.19902108579099106, 0.03331133101820424, 0.01080902054018693, 3.980739602781064e-06, 0.5625024134131904, -55.14968446172642, 0.00011523357069797892, 4.050572617070594, 0.0006181114345366373, 0.003624544943032839, 0.07396905858107695, 3.938334988895222, 0.00031111423951891694, 2.5878686058319946, 3.9582346139622276e-05, 5.047202517142653e-05, -24.615106873325523, 10.539982881654002, 8.86059670041674]
# - running amplitude: 0.45 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.25 on model: ca1_pc_6 at: soma(0.5)
#
# - running amplitude: 0.0 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.05 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_6 at: soma(0.5)
#
# - running amplitude: 0.35000000000000003 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_6 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.4 on model: ca1_pc_6 at: soma(0.5)
#
# - running amplitude: 0.55 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.9500000000000001 on model: ca1_pc_6 at: soma(0.5)
#
# numprocs=1
# - running amplitude: 1.0 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 1.1500000000000001 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_6 at: soma(0.5)numprocs=1
#
# - running amplitude: 1.3 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_6 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_6/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.7000000000000001 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_6/
# The model did not enter depolarization block.
# [-47.31451672012254, 0.012328554000674945, 0.1763659214563141, 0.09725443755483688, 0.017251771349790872, 3.880331262377635e-06, 0.5611571766403177, -52.598406221527824, 0.00010095033740219401, 2.440170802041241, 0.00011272549265684803, 0.0060279416574691306, 0.08105832085105877, 3.8219611316312587, 0.0003741349109792469, 1.651630089516989, 6.604035002586476e-05, 1.9816455880956684e-05, -25.645475638898212, 9.509148681749004, 9.494355706082823]
# - running amplitude: 0.45 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.55 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_7 at: soma(0.5)- running amplitude: 0.25 on model: ca1_pc_7 at: soma(0.5)
#
# - running amplitude: 0.2 on model: ca1_pc_7 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_7 at: soma(0.5)
#
# - running amplitude: 0.9500000000000001 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_7 at: soma(0.5)- running amplitude: 0.75 on model: ca1_pc_7 at: soma(0.5)- running amplitude: 0.6000000000000001 on model: ca1_pc_7 at: soma(0.5)
#
#
# - running amplitude: 0.65 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 1.1500000000000001 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 1.2000000000000002 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_7 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_7/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.8 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.8500000000000001 nA
# Veq (the equilibrium value during the depolarization block): -38.936842134391945 mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_7/
# According to the experiment I_maxNumAP and I_below_depol_block should be equal. If they are not equal a penalty is applied (200 * the difference between them in nA).
# [-45.70061506784235, 0.003570403096842624, 0.16807335532098958, 0.1009286818175892, 0.017525620849071916, 4.585538195703631e-06, 0.5629100538686723, -59.68928291602768, 0.00010454548341151828, 2.3367783718576485, 0.0002519193807863983, 0.003574673600591661, 0.08638069491828596, 4.395065717151833, 0.0002465051651731948, 4.347864023762802, 1.881879876717133e-05, 6.953485849829401e-05, -25.836868420675895, 8.470751052424282, 10.13828126032654]
# - running amplitude: 0.0 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.55 on model: ca1_pc_8 at: soma(0.5)
#
# - running amplitude: 0.45 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.8500000000000001 on model: ca1_pc_8 at: soma(0.5)
#
#
# - running amplitude: 0.1 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_8 at: soma(0.5)
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.4 on model: ca1_pc_8 at: soma(0.5)
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.30000000000000004 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.25 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_8 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 1.1500000000000001 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 1.35 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 1.3 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_8/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_8/
# The model did not enter depolarization block.
# [-46.80183513210604, 0.0076671224287107875, 0.1745835157567751, 0.11549981335981602, 0.01839013652864369, 3.2988317696801607e-06, 0.5792168041642852, -54.92442839624785, 0.00010600340036731842, 2.579504257220232, 0.00043000170998462036, 0.002985333430103456, 0.08725467197795292, 4.297442393609947, 9.299007440363277e-05, 4.086861620147421, 3.110920991678848e-05, 4.4522458947423534e-05, -25.8564313498149, 10.813283404910708, 10.120429902972663]
# - running amplitude: 0.0 on model: ca1_pc_9 at: soma(0.5)- running amplitude: 0.55 on model: ca1_pc_9 at: soma(0.5)
#
# - running amplitude: 0.1 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_9 at: soma(0.5)- running amplitude: 0.4 on model: ca1_pc_9 at: soma(0.5)
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.35000000000000003 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_9 at: soma(0.5)- running amplitude: 0.15000000000000002 on model: ca1_pc_9 at: soma(0.5)
#
# - running amplitude: 0.65 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_9 at: soma(0.5)- running amplitude: 0.8 on model: ca1_pc_9 at: soma(0.5)
#
# - running amplitude: 0.9500000000000001 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.2000000000000002 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.35 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.3 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.4500000000000002 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_9/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.3 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_9/
# The model did not enter depolarization block.
# [-47.046727363856604, 0.009142393231027515, 0.1734564459234941, 0.09038476927965003, 0.01760626754851751, 3.5111827942761145e-06, 0.5637715311977243, -52.58392742050847, 0.0001023862466954727, 2.650293496390263, 0.00012941406042032142, 0.00754367054371495, 0.08183910018142451, 3.9739114505467312, 0.000423559552187225, 2.247546439768558, 5.705436152661179e-05, 7.9192533919979e-06, -25.77133920358794, 10.557520684494044, 9.817720235162609]
# - running amplitude: 0.05 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.15000000000000002 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_10 at: soma(0.5)- running amplitude: 0.6000000000000001 on model: ca1_pc_10 at: soma(0.5)
#
# - running amplitude: 0.35000000000000003 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_10 at: soma(0.5)- running amplitude: 0.7000000000000001 on model: ca1_pc_10 at: soma(0.5)
#
# - running amplitude: 0.8500000000000001 on model: ca1_pc_10 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_10 at: soma(0.5)
#
# - running amplitude: 1.0 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 1.1 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_10/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.8500000000000001 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.9 nA
# Veq (the equilibrium value during the depolarization block): -38.62021598308637 mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_10/
# According to the experiment I_maxNumAP and I_below_depol_block should be equal. If they are not equal a penalty is applied (200 * the difference between them in nA).
# [-46.09618053045715, 0.007775097860383771, 0.16794499539035, 0.11189937512688124, 0.0183234075541897, 2.269642309727379e-06, 0.5907587147759761, -48.80236588926401, 0.00010889338624677877, 2.4313241749123637, 0.0005172129520601723, 0.006652478575514465, 0.08489938140028669, 4.285605165703842, 0.00036595420298276014, 1.3189755297626504, 2.720127640968989e-05, 6.863908662232526e-05, -26.00124057672013, 9.60837790581702, 10.218413562564086]
# - running amplitude: 0.15000000000000002 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_11 at: soma(0.5)- running amplitude: 0.35000000000000003 on model: ca1_pc_11 at: soma(0.5)
#
# - running amplitude: 0.55 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_11 at: soma(0.5)- running amplitude: 0.45 on model: ca1_pc_11 at: soma(0.5)
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.1 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_11 at: soma(0.5)- running amplitude: 0.7000000000000001 on model: ca1_pc_11 at: soma(0.5)
#
# - running amplitude: 0.75 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.0 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 1.05 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 1.35 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 1.55 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_11 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_11/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_11/
# The model did not enter depolarization block.
# [-46.43098921885185, 0.014742147894969953, 0.18316433424759593, 0.059066000395619205, 0.013030258748267933, 3.2672584962106302e-06, 0.5573870454663593, -50.12630565351253, 0.00011472328707127583, 3.1806723735118707, 0.00044112245094793417, 0.0030303792466399933, 0.07808914228801972, 4.2452433171562465, 0.00047148701481152503, 2.0132028363310535, 5.895267277175964e-05, 3.35656479521197e-05, -25.13216844278952, 9.36964860530109, 8.446839225181549]
# - running amplitude: 0.65 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.8500000000000001 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_12 at: soma(0.5)- running amplitude: 0.8 on model: ca1_pc_12 at: soma(0.5)
#
# - running amplitude: 0.05 on model: ca1_pc_12 at: soma(0.5)- running amplitude: 0.9500000000000001 on model: ca1_pc_12 at: soma(0.5)
#
# - running amplitude: 0.9 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.1 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.1500000000000001 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.4500000000000002 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.55 on model: ca1_pc_12 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_12/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.9 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_12/
# The model did not enter depolarization block.
# [-47.72337441637088, 0.01140172013401096, 0.1786616587257201, 0.11053354636193662, 0.018195328014434794, 4.133768197516964e-06, 0.5582806899906827, -55.19770644190086, 0.00010200745484185201, 2.3515157971690615, 0.0001877328584298627, 0.008177991377281032, 0.08260836312643614, 3.6997573520936617, 0.0005811457032595042, 3.69310750687799, 5.1266274824495e-05, 1.1531756152623465e-05, -25.80099593321027, 9.724705579722128, 9.756717519433426]
# - running amplitude: 0.4 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_13 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_13 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_13 at: soma(0.5)
#
#
# - running amplitude: 0.45 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.9 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_13 at: soma(0.5)- running amplitude: 0.05 on model: ca1_pc_13 at: soma(0.5)
#
# - running amplitude: 0.15000000000000002 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 1.1500000000000001 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 1.4500000000000002 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 1.55 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_13 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_13/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.75 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_13/
# The model did not enter depolarization block.
# ...
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 1.3 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 1.55 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_16/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_16/
# The model did not enter depolarization block.
# [-45.25263563551992, 0.011011319765683439, 0.16542040716523546, 0.09696664824745947, 0.017200828644599115, 4.7074021567158434e-06, 0.5625747563975313, -60.39090358552191, 0.0001072903796942765, 2.534787218557705, 0.00017497074544706268, 0.006380469896373111, 0.08537821611193513, 4.576642929336708, 0.00033700176463888543, 2.43049620564932, 1.1775537260123656e-05, 8.17581526201146e-05, -25.923705342390356, 9.26135375322112, 10.27180909931623]
# - running amplitude: 0.0 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.55 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_17 at: soma(0.5)- running amplitude: 0.7000000000000001 on model: ca1_pc_17 at: soma(0.5)
#
# - running amplitude: 0.9500000000000001 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 1.55 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_17/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_17/
# The model did not enter depolarization block.
# [-47.04232285356018, 0.014448704300753238, 0.1759691587314087, 0.09748669054176126, 0.017524984612970376, 3.4947576081841974e-06, 0.5681850997515842, -51.86731303825768, 0.00010042575977660592, 2.8417743946313694, 0.00014034236533534363, 0.003817239362762621, 0.08691578782966701, 4.352097640325149, 0.0004892459145636438, 4.031285327033501, 6.680120400962877e-05, 4.006848484284392e-06, -25.69002193367114, 12.037049953659809, 9.954981527084161]
# - running amplitude: 0.15000000000000002 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.35000000000000003 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.25 on model: ca1_pc_18 at: soma(0.5)
#
# - running amplitude: 0.1 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.8500000000000001 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_18 at: soma(0.5)
#
# - running amplitude: 0.9500000000000001 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.65 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.4000000000000001 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 1.4500000000000002 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 1.55 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.6 on model: ca1_pc_18 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_18/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.8500000000000001 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.9 nA
# Veq (the equilibrium value during the depolarization block): -38.275434708340924 mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_18/
# According to the experiment I_maxNumAP and I_below_depol_block should be equal. If they are not equal a penalty is applied (200 * the difference between them in nA).
# [-46.334610767400285, 0.007645056463057165, 0.16605117797830463, 0.11728809914299926, 0.018910001978398722, 3.458183634000247e-06, 0.5823047224871882, -54.97575597616935, 0.00010914212336452612, 2.4258871033370135, 0.0004784321151919786, 0.0073177215083622404, 0.08530316004083632, 4.300832767935444, 0.0006083125778196826, 0.752198878890235, 2.341805877809951e-05, 5.199033799174357e-05, -26.138874354498995, 9.108443778727151, 9.849452842082997]
# - running amplitude: 0.65 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.9 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.25 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_19 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_19 at: soma(0.5)
#
# - running amplitude: 0.05 on model: ca1_pc_19 at: soma(0.5)- running amplitude: 0.4 on model: ca1_pc_19 at: soma(0.5)
#
# - running amplitude: 0.0 on model: ca1_pc_19 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_19 at: soma(0.5)
#
# - running amplitude: 0.35000000000000003 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_19 at: soma(0.5)- running amplitude: 0.8500000000000001 on model: ca1_pc_19 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.0 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 1.1 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_19 at: soma(0.5)- running amplitude: 1.2000000000000002 on model: ca1_pc_19 at: soma(0.5)
#
# numprocs=1
# numprocs=1
# - running amplitude: 1.25 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.3 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 1.35 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.5 on model: ca1_pc_19 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_19 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_19 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_19/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_19/
# The model did not enter depolarization block.
# [-44.779863188158615, 0.012384064972257365, 0.1701027551021645, 0.20732005736865539, 0.02090060009340788, 3.3119553188343e-06, 0.5595059630220126, -49.32144104834312, 0.00010964756879231327, 3.902440336394697, 0.0002406899967913593, 0.009182574915443794, 0.09208521545202661, 4.65782708909162, 0.0005077990775711956, 1.8251002285794327, 6.482906470567902e-05, 1.1692286846070997e-05, -26.344052889019622, 14.91562730499473, 9.308531296760517]
# - running amplitude: 0.30000000000000004 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.15000000000000002 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.4 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.55 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.35000000000000003 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.05 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.45 on model: ca1_pc_20 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_20 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_20 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_20 at: soma(0.5)
#
# - running amplitude: 0.25 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.75 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.9500000000000001 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_20 at: soma(0.5)- running amplitude: 0.65 on model: ca1_pc_20 at: soma(0.5)
#
# - running amplitude: 0.8500000000000001 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.05 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# - running amplitude: 1.1500000000000001 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.2000000000000002 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 1.25 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 1.35 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 1.3 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 1.4000000000000001 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.4500000000000002 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 1.5 on model: ca1_pc_20 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 1.55 on model: ca1_pc_20 at: soma(0.5)
# - running amplitude: 1.6 on model: ca1_pc_20 at: soma(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/figs/depol_block/ca1_pc_20/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R/results/depol_block/ca1_pc_20/
# The model did not enter depolarization block.

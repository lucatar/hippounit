# %%
#pip install sciunit quantities efel scipy json2html neurom

# %%
#% matplotlib notebook
# %matplotlib inline
from json2html import *
import quantities
from quantities import mV, nA
import IPython
import json
import collections
import pkg_resources
import numpy

#import sciunit
#from hippounit import models
from hippounit import tests
from hippounit.utils_50Ra_major_nmda import ModelLoader_synapse_on_Passive_Spine, ModelLoader_synapse_on_Active_Spine
from hippounit.utils_50Ra_major_nmda import ModelLoader_Modellke, ModelLoader_synapse_on_Existing_Spine
#from hippounit import capabilities
#import matplotlib.pyplot as plt

from neuron import h
# Out:
# Invalid MIT-MAGIC-COOKIE-1 key

# %%
import hippounit
print(hippounit.__file__)
# Out:
# /home/tarluca/Modellke_story/hippounit_Spine_project_20221102/hippounit/hippounit/__init__.py

# %% [markdown]
# # Synapses arrive at dendritic shaft - Active F-factor

# %% [markdown]
# ## Instantiating the model

# %%
#all the outputs will be saved here. It will be an argument to the test.
"""Edit the line below"""
base_directory = '/mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/'

# path to mod files
"""Edit the line below"""
mod_files_path = "/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/mod_files/"

# user function path
"""Edit the line below"""
user_function_path = '/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/usr_fun_model_full_rework7.txt'

#Load cell model
model = ModelLoader_Modellke(mod_files_path = mod_files_path, user_function_path = user_function_path)

# path to hoc file
# the model must not display any GUI!!
"""Edit the line below"""
model.hocpath = "/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/load_model_na_inhomo_minimal_model_full_soma_f_fact_true_diam_active_spine_KA_fact_50Ra.hoc"
# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'soma'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'trunk'
model.TuftSecList_name = 'tuft'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'

model.BasalSecList_name = 'basal_dendrites'

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -70
model.celsius = 33

model.c_step_start = 0.000004
model.c_step_stop = 0.0000004
model.c_minmax = numpy.array([0.000004, 0.004])

# %% [markdown]
# ## Backpropagating Action Potential Test

# %%
# Load target data
"""Edit the line below"""
with open('/home/tarluca/Modellke_story/hippounit_Spine_project_20221102/hippounit/target_features/feat_backpropagating_AP_target_data_ratio.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_AP1_amp_at_50um</th><td>0.8226</td></tr><tr><th>std_AP1_amp_at_50um</th><td>0.0573</td></tr><tr><th>mean_AP1_amp_at_150um</th><td>0.7645</td></tr><tr><th>std_AP1_amp_at_150um</th><td>0.1254</td></tr><tr><th>mean_AP1_amp_at_250um</th><td>0.7136</td></tr><tr><th>std_AP1_amp_at_250um</th><td>0.0896</td></tr><tr><th>mean_AP1_amp_strong_propagating_at_350um</th><td>0.6740</td></tr><tr><th>std_AP1_amp_strong_propagating_at_350um</th><td>0.0752</td></tr><tr><th>mean_AP1_amp_weak_propagating_at_350um</th><td>0.2015</td></tr><tr><th>std_AP1_amp_weak_propagating_at_350um</th><td>0.0519</td></tr><tr><th>mean_APlast_amp_at_50um</th><td>0.7755</td></tr><tr><th>std_APlast_amp_at_50um</th><td>0.0616</td></tr><tr><th>mean_APlast_amp_at_150um</th><td>0.5522</td></tr><tr><th>std_APlast_amp_at_150um</th><td>0.1120</td></tr><tr><th>mean_APlast_amp_at_250um</th><td>0.3045</td></tr><tr><th>std_APlast_amp_at_250um</th><td>0.0315</td></tr><tr><th>mean_APlast_amp_at_350um</th><td>0.1546</td></tr><tr><th>std_APlast_amp_at_350um</th><td>0.0675</td></tr></table>

# %%
#stimuli
import pkg_resources
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/bAP_stim/stim_bAP_test.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Instantiate the test class
test = tests.BackpropagatingAPTest2(observation = observation, config=config, save_all = True, force_run=True, force_run_FindCurrentStim=True, show_plot = True, base_directory = base_directory)

# Number of parallel processes
test.npool = 20

"""Edit the line below"""
f = open('/home/tarluca/Modellke_story/Luca_modell_rework_2/prep_and_run_model_rework_new_K_stuff/nsg_csomag_model_rework_new/results_ca1_results/last_13_blocking.csv')
lines = []
for l in f.readlines():
    #print l.strip().split(',')
    lines.append(l.strip().split(','))
f.close()

for i in range(1, len(lines)):
    parameters = [float(j) for j in lines[i]]
    #lines[i].pop(0)
    parameters.pop(0)
    print(parameters)
    
    model.parameters = parameters
    # outputs will be saved in folders named like this:
    """Edit the line below"""
    model.name="ca1_pc_"+str(i)
    if numpy.isnan(parameters[0]):
        print('Parameters are nan')
        pass
    else:
        try:
            #Run the test 
            score = test.judge(model)
            #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
            score.summarize()

        except Exception as e:
            print('Model: ' + model.name + ' could not be run')
            print(e)
            pass
# Out:
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.0 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_1 at: soma(0.5)
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_1 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_1 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_1 at: soma(0.5)
#
# - running amplitude: 1.0 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.13999999999999999 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_1 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_1/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.0, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.1 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_2 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_2 at: soma(0.5)- running amplitude: 0.7000000000000001 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_2 at: soma(0.5)
#
# - running amplitude: 0.9 on model: ca1_pc_2 at: soma(0.5)
# - running amplitude: 0.13999999999999999 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_2 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_2/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.0, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.8 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_3 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_3 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_3 at: soma(0.5)
#
#
# - running amplitude: 0.9 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_3 at: soma(0.5)- running amplitude: 1.0 on model: ca1_pc_3 at: soma(0.5)
#
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_3 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# The model fired at 0 Hz to 1.0 nA current step, and did not reach 10 Hz firing rate as supposed (according to Bianchi et al 2012 Fig. 1 B eg.)
# Model: ca1_pc_3 could not be run
# '<' not supported between instances of 'NoneType' and 'int'
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.0, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.0 on model: ca1_pc_4 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_4 at: soma(0.5)
#
# - running amplitude: 0.5 on model: ca1_pc_4 at: soma(0.5)- running amplitude: 0.6000000000000001 on model: ca1_pc_4 at: soma(0.5)
#
# - running amplitude: 0.8 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_4 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_4 at: soma(0.5)
#
# - running amplitude: 0.4 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_4 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.2 on model: ca1_pc_4 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_4/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.0, 0.17866165872572, 0.0, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.6000000000000001 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.30000000000000004 on model: ca1_pc_5 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_5 at: soma(0.5)
#
# - running amplitude: 0.2 on model: ca1_pc_5 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_5 at: soma(0.5)
#
# - running amplitude: 0.5 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_5 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_5 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_5/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.0, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.1 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.4 on model: ca1_pc_6 at: soma(0.5)
#
# - running amplitude: 0.0 on model: ca1_pc_6 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_6 at: soma(0.5)
#
# - running amplitude: 0.8 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 1.0 on model: ca1_pc_6 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_6 at: soma(0.5)
#
#
# - running amplitude: 0.30000000000000004 on model: ca1_pc_6 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# Spontaneous firing
# Model: ca1_pc_6 could not be run
# '<' not supported between instances of 'NoneType' and 'int'
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.0, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.7000000000000001 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.30000000000000004 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_7 at: soma(0.5)- running amplitude: 1.0 on model: ca1_pc_7 at: soma(0.5)
#
# - running amplitude: 0.9 on model: ca1_pc_7 at: soma(0.5)
# - running amplitude: 0.13999999999999999 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15999999999999998 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14500000000000005 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.17000000000000007 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15500000000000005 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15500000000000005 on model: ca1_pc_7 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_7/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.0, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.30000000000000004 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_8 at: soma(0.5)
#
# - running amplitude: 0.0 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_8 at: soma(0.5)numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
#
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_8 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_8 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.04 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.01 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.02 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.045 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.02 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.005 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.01 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.015 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.0475 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.0225 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.01 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.015 on model: ca1_pc_8 at: soma(0.5)
# - running amplitude: 0.0125 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# WARNING: No current amplitude value has been found to which the model's firing frequency is between 10 and 20 Hz. The simulation is done using the current amplitude value to which the models fires at a frequency nearest to 15 Hz, but not 0 Hz. Current step amplitude: 0.0125nA, frequency: [26]Hz
#
# - running amplitude: 0.0125 on model: ca1_pc_8 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_8/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 0.0, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.0 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_9 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_9 at: soma(0.5)
#
# - running amplitude: 0.4 on model: ca1_pc_9 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_9 at: soma(0.5)
#
# - running amplitude: 0.7000000000000001 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_9 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.2 on model: ca1_pc_9 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_9/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.0, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.2 on model: ca1_pc_10 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_10 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.5 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_10 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_10 at: soma(0.5)
#
# - running amplitude: 0.0 on model: ca1_pc_10 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_10 at: soma(0.5)
#
# - running amplitude: 0.4 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.13999999999999999 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.14500000000000005 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.17000000000000007 on model: ca1_pc_10 at: soma(0.5)
# - running amplitude: 0.15500000000000005 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15000000000000005 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14750000000000005 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14750000000000005 on model: ca1_pc_10 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_10/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.0, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.0, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.5 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_11 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_11 at: soma(0.5)
#
# - running amplitude: 0.6000000000000001 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_11 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_11 at: soma(0.5)- running amplitude: 0.8 on model: ca1_pc_11 at: soma(0.5)
#
#
# - running amplitude: 0.9 on model: ca1_pc_11 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_11 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# Spontaneous firing
# Model: ca1_pc_11 could not be run
# '<' not supported between instances of 'NoneType' and 'int'
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.0, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.2 on model: ca1_pc_12 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_12 at: soma(0.5)
#
# - running amplitude: 0.0 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_12 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_12 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_12 at: soma(0.5)- running amplitude: 0.8 on model: ca1_pc_12 at: soma(0.5)
#
#
# - running amplitude: 0.9 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.13999999999999999 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15999999999999998 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14500000000000005 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.17000000000000007 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15500000000000005 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15500000000000005 on model: ca1_pc_12 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_12/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.0, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.0 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.1 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.2 on model: ca1_pc_13 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_13 at: soma(0.5)
#
# - running amplitude: 0.5 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_13 at: soma(0.5)- running amplitude: 0.7000000000000001 on model: ca1_pc_13 at: soma(0.5)
#
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.13999999999999999 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.15999999999999998 on model: ca1_pc_13 at: soma(0.5)
# - running amplitude: 0.14500000000000005 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.17000000000000007 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15500000000000005 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15500000000000005 on model: ca1_pc_13 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_13/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 0.0, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.8 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_14 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_14 at: soma(0.5)
#
# - running amplitude: 0.30000000000000004 on model: ca1_pc_14 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_14 at: soma(0.5)- running amplitude: 0.6000000000000001 on model: ca1_pc_14 at: soma(0.5)
#
#
# - running amplitude: 0.5 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_14 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.13999999999999999 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.16999999999999998 on model: ca1_pc_14 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_14 at: soma(0.5)
# - running amplitude: 0.14999999999999997 on model: ca1_pc_14 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_14/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.0, 3.69310750687799, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 1.0 on model: ca1_pc_15 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.4 on model: ca1_pc_15 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_15 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_15 at: soma(0.5)
#
#
# - running amplitude: 0.2 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.30000000000000004 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_15 at: soma(0.5)- running amplitude: 0.6000000000000001 on model: ca1_pc_15 at: soma(0.5)
#
# - running amplitude: 0.8 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_15 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.13999999999999999 on model: ca1_pc_15 at: soma(0.5)
# - running amplitude: 0.16999999999999998 on model: ca1_pc_15 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_15 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_15 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_15/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 0.0, 5.1266274824495e-05, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.1 on model: ca1_pc_16 at: soma(0.5)- running amplitude: 0.2 on model: ca1_pc_16 at: soma(0.5)- running amplitude: 0.4 on model: ca1_pc_16 at: soma(0.5)
#
# - running amplitude: 0.30000000000000004 on model: ca1_pc_16 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_16 at: soma(0.5)
#
#
# - running amplitude: 0.8 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.5 on model: ca1_pc_16 at: soma(0.5)- running amplitude: 0.6000000000000001 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_16 at: soma(0.5)
#
# - running amplitude: 1.0 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.9 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.13999999999999999 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.15999999999999998 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14500000000000005 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# numprocs=1
# - running amplitude: 0.17000000000000007 on model: ca1_pc_16 at: soma(0.5)
# - running amplitude: 0.15500000000000005 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.15500000000000005 on model: ca1_pc_16 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_16/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 0.0, 1.15317561526235e-05, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.1 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.8 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.2 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.0 on model: ca1_pc_17 at: soma(0.5)- running amplitude: 0.30000000000000004 on model: ca1_pc_17 at: soma(0.5)
#
# - running amplitude: 0.5 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.4 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.7000000000000001 on model: ca1_pc_17 at: soma(0.5)- running amplitude: 0.6000000000000001 on model: ca1_pc_17 at: soma(0.5)
#
# - running amplitude: 0.9 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 1.0 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.13999999999999999 on model: ca1_pc_17 at: soma(0.5)
# - running amplitude: 0.11 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.12 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.13 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.13 on model: ca1_pc_17 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_17/
# This is a rather STRONG propagating model
# [-47.7233744163709, 0.011401720134011, 0.17866165872572, 0.110533546361937, 0.018195328014435, 4.13376819751696e-06, 0.558280689990683, -55.1977064419009, 0.000102007454842, 2.35151579716906, 0.00018773285843, 0.008177991377281, 0.082608363126436, 3.69975735209366, 0.00058114570326, 3.69310750687799, 5.1266274824495e-05, 0.0, -25.8009959332103, 9.72470557972213, 9.75671751943343]
# numprocs=1
# Dendritic locations to be tested (with their actual distances): {('dendrite[4]', 0.5): 44.010248981764285, ('dendrite[13]', 0.5): 45.759404409481654, ('dendrite[31]', 0.5): 51.874440048986514, ('dendrite[55]', 0.5): 64.04833266564478, ('dendrite[85]', 0.5): 147.38275623716865, ('dendrite[87]', 0.5): 158.77871747375843, ('dendrite[91]', 0.5): 166.10161451767556, ('dendrite[109]', 0.5): 232.2961368839031, ('dendrite[113]', 0.5): 247.82975267606994, ('dendrite[135]', 0.5): 335.58030914634867, ('dendrite[139]', 0.5): 344.2805632417561}
# Finding appropriate current step amplitude...
# - running amplitude: 0.30000000000000004 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.6000000000000001 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# numprocs=1
# - running amplitude: 0.2 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.0 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.1 on model: ca1_pc_18 at: soma(0.5)
#
#
# - running amplitude: 0.4 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.5 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.7000000000000001 on model: ca1_pc_18 at: soma(0.5)
#
#
# - running amplitude: 0.8 on model: ca1_pc_18 at: soma(0.5)- running amplitude: 0.9 on model: ca1_pc_18 at: soma(0.5)
#
# - running amplitude: 1.0 on model: ca1_pc_18 at: soma(0.5)
# - running amplitude: 0.13999999999999999 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.16999999999999998 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# - running amplitude: 0.14999999999999997 on model: ca1_pc_18 at: soma(0.5)
# numprocs=1
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/CA1_pyramidal/Spine_project_validation_results60/Basic_set_newopt/Shaft_active_F_factor_with_R_blocking/figs/backpropagating_AP2/ca1_pc_18/
# This is a rather STRONG propagating model
